# %% [markdown]
# <a href="https://colab.research.google.com/github/manashvinidave65-md/campus-complaint-intelligence/blob/main/01_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Campus Complaint Intelligence")
# Out:
# Campus Complaint Intelligence

# %%
import sys

print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
